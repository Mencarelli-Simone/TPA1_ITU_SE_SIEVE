# %%
import pandas as pd
import numpy as np
import os
from IPython.display import display
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from ITUtils import *
from tqdm.notebook import tqdm

pd.set_option('display.max_rows', None)

# %%
countries_folder = './countriestables'
# load all tables from the folders into a single pd file
# Initialize an empty list to store DataFrames
dataframes = []

# Loop through all files in the folder
for filename in os.listdir(countries_folder):
    if filename.endswith('.csv'):  # Assuming the tables are in CSV format
        filepath = os.path.join(countries_folder, filename)
        df = pd.read_csv(filepath)
        dataframes.append(df)

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# Display the combined DataFrame
display(combined_df.head())
# print all the column names
print(combined_df.columns)
# Out:
# C:\Users\smen851\AppData\Local\Temp\ipykernel_25692\2093958420.py:10: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath)
# C:\Users\smen851\AppData\Local\Temp\ipykernel_25692\2093958420.py:10: DtypeWarning: Columns (20,22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath)
# C:\Users\smen851\AppData\Local\Temp\ipykernel_25692\2093958420.py:10: DtypeWarning: Columns (3,20,22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath)
# C:\Users\smen851\AppData\Local\Temp\ipykernel_25692\2093958420.py:10: DtypeWarning: Columns (20,22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath)
#    com_el.ntc_id   com_el.tgt_ntc_id  com_el.adm  com_el.ntwk_org  \
# 0      117545401                 NaN         AFS              NaN
# 1      120545101                 NaN         AFS              NaN
# 2      121545063                 NaN         AFS              NaN
# 3      117545401                 NaN         AFS              NaN
# 4      121545063                 NaN         AFS              NaN
#
#    com_el.sat_name   com_el.long_nom  com_el.prov  com_el.d_rcv  \
# 0         ZACUBE-2               NaN       9.1/IA    15.12.2017
# 1         MDASAT-1               NaN       9.1/IA    13.05.2020
# 2    EOS AGRISAT-1               NaN       9.1/IA    28.03.2021
# 3         ZACUBE-2               NaN       9.1/IA    15.12.2017
# 4    EOS AGRISAT-1               NaN       9.1/IA    28.03.2021
#
#     com_el.st_cur   orbit.orb_id  ...   grp.freq_max   grp.bdwdth  \
# 0              50            1.0  ...          402.0          NaN
# 1              50            1.0  ...          402.0          NaN
# 2              50            1.0  ...         2110.0          NaN
# 3              50            1.0  ...         2290.0          NaN
# 4              50            1.0  ...         2290.0          NaN
#
#     grp.d_inuse   grp.d_reg_limit  grp.d_prot_eff  grp.f_biu   emiss.seq_no  \
# 0           NaN        15.12.2024             NaN        NaN            1.0
# 1           NaN        13.05.2027             NaN        NaN            1.0
# 2           NaN        28.03.2028             NaN        NaN            1.0
# 3           NaN        15.12.2024             NaN        NaN            1.0
# 4           NaN        28.03.2028             NaN        NaN            1.0
#
#     emiss.pwr_ds_max   emiss.design_emi   carrier_fr.freq_carr
# 0              -37.0          9K50F1DBN                  401.5
# 1              -37.0          9K50F1DBN                  401.0
# 2              -46.8          1M20G1DBN                 2030.0
# 3              -65.0          6M40G2DDN                 2225.0
# 4              -59.1          680KG1DDN                 2235.0
#
# [5 rows x 28 columns]
# Index(['com_el.ntc_id', ' com_el.tgt_ntc_id', ' com_el.adm',
#        ' com_el.ntwk_org', ' com_el.sat_name', ' com_el.long_nom',
#        ' com_el.prov', ' com_el.d_rcv', ' com_el.st_cur', ' orbit.orb_id',
#        ' orbit.nbr_sat_pl', ' orbit.apog_km', ' orbit.perig_km',
#        ' orbit.op_ht_km', ' s_beam.emi_rcp', ' s_beam.beam_name',
#        ' grp.grp_id', ' grp.freq_min', ' grp.freq_max', ' grp.bdwdth',
#        ' grp.d_inuse', ' grp.d_reg_limit', ' grp.d_prot_eff', ' grp.f_biu',
#        ' emiss.seq_no', ' emiss.pwr_ds_max', ' emiss.design_emi',
#        ' carrier_fr.freq_carr'],
#       dtype='object')

# %%
# get the reference database for tpa
tpafile = './databases/TPAtable.csv'
tpa_df = pd.read_csv(tpafile)
display(tpa_df)
# Out:
#     com_el.ntc_id   com_el.tgt_ntc_id  com_el.adm   com_el.ntwk_org  \
# 0       124545322                 NaN         NZL               NaN
# 1       124545322                 NaN         NZL               NaN
# 2       124545322                 NaN         NZL               NaN
# 3       124545322                 NaN         NZL               NaN
# 4       124545322                 NaN         NZL               NaN
# 5       124545322                 NaN         NZL               NaN
# 6       124545322                 NaN         NZL               NaN
# 7       124545322                 NaN         NZL               NaN
# 8       124545322                 NaN         NZL               NaN
# 9       124545322                 NaN         NZL               NaN
# 10      124545322                 NaN         NZL               NaN
# 11      124545322                 NaN         NZL               NaN
#
#     com_el.sat_name   com_el.long_nom  com_el.ntc_type  com_el.prov  \
# 0             TPA-1               NaN                N       9.1/IA
# 1             TPA-1               NaN                N       9.1/IA
# 2             TPA-1               NaN                N       9.1/IA
# 3             TPA-1               NaN                N       9.1/IA
# 4             TPA-1               NaN                N       9.1/IA
# 5             TPA-1               NaN                N       9.1/IA
# 6             TPA-1               NaN                N       9.1/IA
# 7             TPA-1               NaN                N       9.1/IA
# 8             TPA-1               NaN                N       9.1/IA
# 9             TPA-1               NaN                N       9.1/IA
# 10            TPA-1               NaN                N       9.1/IA
# 11            TPA-1               NaN                N       9.1/IA
#
#     com_el.ntf_rsn  com_el.d_rcv  ...   grp.freq_min   grp.freq_max  \
# 0                A    04.10.2024  ...        401.825          402.0
# 1                A    04.10.2024  ...        401.825          402.0
# 2                A    04.10.2024  ...       2055.000         2075.0
# 3                A    04.10.2024  ...        401.825          402.0
# 4                A    04.10.2024  ...       2202.000         2239.0
# 5                A    04.10.2024  ...       2055.000         2075.0
# 6                A    04.10.2024  ...        401.825          402.0
# 7                A    04.10.2024  ...        401.825          402.0
# 8                A    04.10.2024  ...        401.825          402.0
# 9                A    04.10.2024  ...        401.825          402.0
# 10               A    04.10.2024  ...        401.825          402.0
# 11               A    04.10.2024  ...       2202.000         2239.0
#
#      grp.bdwdth   emiss.seq_no   emiss.pwr_ds_max  emiss.design_emi  \
# 0           NaN              2              -55.0         9K50F1DAN
# 1           NaN              1              -55.0         19K8F1DAN
# 2           NaN              1              -41.0         250KM1DAN
# 3           NaN              2              -55.0         9K50F1DAN
# 4           NaN              1              -55.8         1M00M1DAN
# 5           NaN              1              -41.0         250KM1DAN
# 6           NaN              1              -39.8         19K8F1DAN
# 7           NaN              1              -55.0         19K8F1DAN
# 8           NaN              2              -39.8         9K50F1DAN
# 9           NaN              1              -39.8         19K8F1DAN
# 10          NaN              2              -39.8         9K50F1DAN
# 11          NaN              1              -55.8         1M00M1DAN
#
#     carrier_fr.freq_carr   channel.bandwidth   channel.freq_min  \
# 0                 401.96              9500.0          401.95525
# 1                 401.96             19800.0          401.95010
# 2                2055.60            250000.0         2055.47500
# 3                 401.90              9500.0          401.89525
# 4                2237.50           1000000.0         2237.00000
# 5                2065.70            250000.0         2065.57500
# 6                 401.96             19800.0          401.95010
# 7                 401.90             19800.0          401.89010
# 8                 401.96              9500.0          401.95525
# 9                 401.90             19800.0          401.89010
# 10                401.90              9500.0          401.89525
# 11               2202.90           1000000.0         2202.40000
#
#      channel.freq_max
# 0           401.96475
# 1           401.96990
# 2          2055.72500
# 3           401.90475
# 4          2238.00000
# 5          2065.82500
# 6           401.96990
# 7           401.90990
# 8           401.96475
# 9           401.90990
# 10          401.90475
# 11         2203.40000
#
# [12 rows x 28 columns]

# %%
# find all conflicts

num_logical_processors = os.cpu_count()
pandarallel.initialize(nb_workers=num_logical_processors, progress_bar=True)
combined_conflicts, notfound = conflicts_appender(combined_df, tpa_df)
# Out:
# INFO: Pandarallel will run on 16 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
#
# WARNING: You are on Windows. If you detect any issue with pandarallel, be sure you checked out the Troubleshooting page:
# https://nalepae.github.io/pandarallel/troubleshooting/
# INFO: Pandarallel will run on 16 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
#
# WARNING: You are on Windows. If you detect any issue with pandarallel, be sure you checked out the Troubleshooting page:
# https://nalepae.github.io/pandarallel/troubleshooting/
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=126986), Label(value='0 / 126986')…
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25692\515682719.py in ?()
#       1 # find all conflicts
#       2
#       3 num_logical_processors = os.cpu_count()
#       4 pandarallel.initialize(nb_workers=num_logical_processors, progress_bar=True)
# ----> 5 combined_conflicts, notfound = conflicts_appender(combined_df, tpa_df)
#
# ~\PycharmProjects\TPA1_ITU_SE_SIEVE\ITUtils.py in ?(targetdf, referencedf)
#     107         percent_overlap_str = ":".join(percent_overlap_list)
#     108         return conflicts, percent_overlap_str
#     109
#     110     # Apply the function to each row of the ddf DataFrame in parallel
# --> 111     ddf['tpaconflicts', 'percentoverlap'] = ddf.parallel_apply(
#     112         lambda row: check_overlap(row, referencedf), axis=1, result_type='expand'
#     113     )
#     114
#
# ~\PycharmProjects\TPA1_ITU_SE_SIEVE\.venv\lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4297             self._setitem_frame(key, value)
#    4298         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4299             self._setitem_array(key, value)
#    4300         elif isinstance(value, DataFrame):
# -> 4301             self._set_item_frame_value(key, value)
#    4302         elif (
#    4303             is_list_like(value)
#    4304             and not self.columns.is_unique
#
# ~\PycharmProjects\TPA1_ITU_SE_SIEVE\.venv\lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4455
#    4456             return self.isetitem(locs, value)
#    4457
#    4458         if len(value.columns) > 1:
# -> 4459             raise ValueError(
#    4460                 "Cannot set a DataFrame with multiple columns to the single "
#    4461                 f"column {key}"
#    4462             )
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column ('tpaconflicts', 'percentoverlap')

# %%
display(combined_conflicts.head())
display(notfound.head())
# save to csv with conflict 
combined_conflicts.to_csv('./databases/combined_tables_conflicts.csv', index=False)
print('file ./databases/combined_tables_conflicts.csv created')
